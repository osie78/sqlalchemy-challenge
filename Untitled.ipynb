# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func
import pandas as pd
import datetime as dt
from datetime import date
import numpy as np

# %%
# Create engine using the `demographics.sqlite` database file
engine = create_engine("sqlite:///hawaii.sqlite")

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# %%
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)

# %%
# View all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement=Base.classes.measurement
Station=Base.classes.station

# %%
# Create our session (link) from Python to the DB
session=Session(engine)

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
first_row = session.query(Measurement).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1c4567944c0>,
#  'tobs': 65.0,
#  'station': 'USC00519397',
#  'date': '2010-01-01',
#  'id': 1,
#  'prcp': 0.08}

# %%
q_measurement=session.query(Measurement)

# %%
last_measurement=session.query(Measurement.date).order_by(Measurement.date.desc()).first()
print(last_measurement)
# Out:
# ('2017-08-23',)

# %%
print(f'the most recent date is {last_measurement}')
# Out:
# the most recent date is ('2017-08-23',)

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
date1=[]
prec1=[]
query_12_months = q_measurement.filter(Measurement.date.between('2016-08-23', '2017-08-23'))
for x in query_12_months:
    date1.append(x.date)
    prec1.append(x.prcp)
    print(x.date,x.prcp)
# Out:
# 2016-08-23 0.0
# 2016-08-24 0.08
# 2016-08-25 0.08
# 2016-08-26 0.0
# 2016-08-27 0.0
# 2016-08-28 0.01
# 2016-08-29 0.0
# 2016-08-30 0.0
# 2016-08-31 0.13
# 2016-09-01 0.0
# 2016-09-02 0.0
# 2016-09-03 0.0
# 2016-09-04 0.03
# 2016-09-05 None
# 2016-09-06 None
# 2016-09-07 0.05
# 2016-09-08 0.0
# 2016-09-09 0.03
# 2016-09-10 0.0
# 2016-09-11 0.05
# 2016-09-12 0.0
# 2016-09-13 0.02
# 2016-09-14 1.32
# 2016-09-15 0.42
# 2016-09-16 0.06
# 2016-09-17 0.05
# 2016-09-18 0.0
# 2016-09-19 0.0
# 2016-09-20 0.0
# 2016-09-21 0.0
# 2016-09-22 0.02
# 2016-09-23 0.0
# 2016-09-24 0.0
# 2016-09-25 0.0
# 2016-09-26 0.06
# 2016-09-27 0.02
# 2016-09-28 0.0
# 2016-09-29 0.0
# 2016-09-30 0.0
# 2016-10-01 0.0
# 2016-10-02 0.0
# 2016-10-03 0.0
# 2016-10-04 0.0
# 2016-10-05 0.0
# 2016-10-06 0.0
# 2016-10-07 0.0
# 2016-10-08 0.0
# 2016-10-09 0.0
# 2016-10-10 0.0
# 2016-10-11 0.0
# 2016-10-12 0.0
# 2016-10-13 0.0
# 2016-10-14 0.0
# 2016-10-15 0.0
# 2016-10-16 0.0
# 2016-10-17 0.01
# 2016-10-18 0.0
# ...

# %%
date1_df=pd.DataFrame(date1)
prec1_df=pd.DataFrame(prec1)

# %%
date1_df['Date']=pd.DataFrame(date1)
prec1_df['Precipitation']=pd.DataFrame(prec1)

prec_1y_df= pd.concat([date1_df,prec1_df], axis=1)
del prec_1y_df[0]

prec_1y_df=prec_1y_df.dropna(subset=['Precipitation'])
prec_1y_df
# Out:
#             Date  Precipitation
# 0     2016-08-23           0.00
# 1     2016-08-24           0.08
# 2     2016-08-25           0.08
# 3     2016-08-26           0.00
# 4     2016-08-27           0.00
# ...          ...            ...
# 2223  2017-08-17           0.13
# 2225  2017-08-19           0.09
# 2227  2017-08-21           0.56
# 2228  2017-08-22           0.50
# 2229  2017-08-23           0.45
#
# [2021 rows x 2 columns]

# %%
#bars=prec_1y_df.plot.bar(x='Date',y='Precipitation')
x_axis=np.arange(len(prec_1y_df))
plt.bar()
# Out:
# array([   0,    1,    2, ..., 2018, 2019, 2020])

# %% [markdown]
# #### Statistical analysis

# %%
avg_p=prec_1y_df['Precipitation'].mean()
med_p=prec_1y_df['Precipitation'].median()
st_p=prec_1y_df['Precipitation'].std()
print(f'the mean precipitation in the 12 months period was {avg_p}')
print(f'the median precipitation in the 12 months period was {med_p}')
print(f'the standard deviation in the 12 months period was {st_p}')
# Out:
# the mean precipitation in the 12 months period was 0.17727857496288996
# the median precipitation in the 12 months period was 0.02
# the standard deviation in the 12 months period was 0.4611895038877028

# %% [markdown]
# ## Station Analysis

# %%
# Design a query to calculate the total number stations in the dataset
f_row = session.query(Station).first()
f_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1c456f516a0>,
#  'latitude': 21.2716,
#  'station': 'USC00519397',
#  'longitude': -157.8168,
#  'name': 'WAIKIKI 717.2, HI US',
#  'id': 1,
#  'elevation': 3.0}

# %%
number_stations=session.query(Station.name).count()
print(f'there are {number_stations} stations reporting')
# Out:
# there are 9 stations reporting

# %%
count_per_station=session.query(Measurement.station, func.count(Measurement.station)).group_by(Measurement.station).all()
count_per_station_df=pd.DataFrame.from_records(count_per_station, columns=['station', 'records'])

max_records=count_per_station_df['records'].max()
#max_records

max_act=count_per_station_df.loc[count_per_station_df['records'] == 2772]
max_act_station=max_act[['station']]
print(f'the station with the highest activity is {max_act_station}')
# Out:
# the station with the highest activity is        station
# 6  USC00519281

# %%
count_per_station_df.sort_values(by=['records'], ascending=False)
# Out:
#        station  records
# 6  USC00519281     2772
# 7  USC00519397     2724
# 1  USC00513117     2709
# 8  USC00519523     2669
# 3  USC00516128     2612
# 2  USC00514830     2202
# 0  USC00511918     1979
# 4  USC00517948     1372
# 5  USC00518838      511

# %% [markdown]
# ### Calculating min, max and average temperature for the most active station

# %%
q_temp_max=session.query(Measurement.tobs,func.max(Measurement.tobs)).filter_by(station='USC00519281').all()

print(f' the max observed temp is {q_temp_max[0][0]}')
# Out:
#  the max observed temp is 85.0

# %%
q_temp_min=session.query(Measurement.tobs,func.min(Measurement.tobs)).filter_by(station='USC00519281').all()
print(f' the min observed temp is {q_temp_min[0][0]}')
# Out:
#  the min observed temp is 54.0

# %%
q_temp_avg=session.query(Measurement.tobs,func.avg(Measurement.tobs)).filter_by(station='USC00519281').all()
print(f' the average observed temp is {q_temp_avg[0][0]}')
# Out:
#  the average observed temp is 70.0

# %% [markdown]
# ### Design a query to retrieve the last 12 months of temperature observation data (TOBS).

# %%
date2=[]
temp1=[]
station=[]
query_12_months = q_measurement.filter(Measurement.date.between('2016-08-23', '2017-08-23'))

for y in query_12_months:
    date2.append(y.date)
    station.append(y.station)
    temp1.append(y.tobs)
    print(y.date,y.station,y.tobs)
# Out:
# 2016-08-23 USC00519397 81.0
# 2016-08-24 USC00519397 79.0
# 2016-08-25 USC00519397 80.0
# 2016-08-26 USC00519397 79.0
# 2016-08-27 USC00519397 77.0
# 2016-08-28 USC00519397 78.0
# 2016-08-29 USC00519397 78.0
# 2016-08-30 USC00519397 79.0
# 2016-08-31 USC00519397 80.0
# 2016-09-01 USC00519397 81.0
# 2016-09-02 USC00519397 80.0
# 2016-09-03 USC00519397 79.0
# 2016-09-04 USC00519397 75.0
# 2016-09-05 USC00519397 79.0
# 2016-09-06 USC00519397 76.0
# 2016-09-07 USC00519397 76.0
# 2016-09-08 USC00519397 80.0
# 2016-09-09 USC00519397 79.0
# 2016-09-10 USC00519397 78.0
# 2016-09-11 USC00519397 76.0
# 2016-09-12 USC00519397 78.0
# 2016-09-13 USC00519397 78.0
# 2016-09-14 USC00519397 75.0
# 2016-09-15 USC00519397 79.0
# 2016-09-16 USC00519397 80.0
# 2016-09-17 USC00519397 79.0
# 2016-09-18 USC00519397 81.0
# 2016-09-19 USC00519397 77.0
# 2016-09-20 USC00519397 77.0
# 2016-09-21 USC00519397 78.0
# 2016-09-22 USC00519397 76.0
# 2016-09-23 USC00519397 82.0
# 2016-09-24 USC00519397 81.0
# ...

# %%
date2_df['Date']=pd.DataFrame(date2)
temp1_df['Temp']=pd.DataFrame(temp1)
station_df['Station']=pd.DataFrame(station)

temp_1y_df= pd.concat([date2_df,temp1_df,station_df], axis=1)
del temp_1y_df[0]

temp_1y_df=temp_1y_df.dropna(subset=['Temp']) # deleting null values in temperatures

temp_1y_df
# Out:
#             Date  Temp      Station
# 0     2016-08-23  81.0  USC00519397
# 1     2016-08-24  79.0  USC00519397
# 2     2016-08-25  80.0  USC00519397
# 3     2016-08-26  79.0  USC00519397
# 4     2016-08-27  77.0  USC00519397
# ...          ...   ...          ...
# 2225  2017-08-19  71.0  USC00516128
# 2226  2017-08-20  78.0  USC00516128
# 2227  2017-08-21  76.0  USC00516128
# 2228  2017-08-22  76.0  USC00516128
# 2229  2017-08-23  76.0  USC00516128
#
# [2230 rows x 3 columns]

# %%
most_act_temp=temp_1y_df.groupby('Station').count()
most_act_temp[['Temp']]
# Out:
#              Temp
# Station
# USC00513117   343
# USC00514830   305
# USC00516128   349
# USC00517948   183
# USC00519281   352
# USC00519397   361
# USC00519523   337

# %%
t_most_act_station=temp_1y_df.loc[(temp_1y_df['Station'] == 'USC00513117')].Temp
t_most_act_station_df=pd.DataFrame(t_most_act_station)
t_most_act_station_df
# Out:
#      Temp
# 361  76.0
# 362  76.0
# 363  77.0
# 364  78.0
# 365  73.0
# ..    ...
# 699  77.0
# 700  77.0
# 701  78.0
# 702  78.0
# 703  77.0
#
# [343 rows x 1 columns]

# %%
hist=t_most_act_station_df.hist(bins=12)

plt.ylabel('Frequency')
plt.xlabel('Temperature')
plt.show()

# %%
## Close session
session.close()
